# %% [markdown]
# # Getting Started with Triton Notebook

# %% [markdown]
# A cell is either **Markdown mode** or **Code mode** as indicated in the toolbar above. Code mode is where we enter shell command or Python/R code.
#
#
# Type `%%bash` at the top of a cell to enter a shell command/script.

# %%
# %%bash
#
# echo "hello world"
# Out:
# hello world

# %% [markdown]
# # Bioinformatics notebook

# %% [markdown]
# Here is a list of bioinformatics tools available in the system.

# %%
# %%bash
#
# find ~/.local/bin -type f -executable -print0 | xargs -0 basename -a | sort
# Out:
# 7z
# a
# actions.sh
# add.d.ts
# add.d.ts
# addr2line
# after.d.ts
# after.d.ts
# align.js
# align.js
# all.bash
# all.d.ts
# allPass.d.ts
# all.rc
# always.d.ts
# any.d.ts
# anyPass.d.ts
# apply.d.ts
# array.d.ts
# ary.d.ts
# ary.d.ts
# asm
# assignAll.d.ts
# assignAllWith.d.ts
# assign.d.ts
# assign.d.ts
# assignInAll.d.ts
# assignInAllWith.d.ts
# assignIn.d.ts
# assignIn.d.ts
# assignInWith.d.ts
# assignInWith.d.ts
# assignWith.d.ts
# assignWith.d.ts
# assoc.d.ts
# assocPath.d.ts
# at.d.ts
# at.d.ts
# attempt.d.ts
# attempt.d.ts
# bat
# before.d.ts
# before.d.ts
# bindAll.d.ts
# bindAll.d.ts
# bind.d.ts
# bind.d.ts
# bindKey.d.ts
# bindKey.d.ts
# bin.js
# bin.js
# bin.js
# bin.js
# bin.js
# bin.js
# bootstrap.bash
# broot
# buildall.bash
# buildid
# build.js
# camelCase.d.ts
# camelCase.d.ts
# capitalize.d.ts
# capitalize.d.ts
# castArray.d.ts
# castArray.d.ts
# cb
# ceil.d.ts
# ceil.d.ts
# cgo
# chain.d.ts
# changelog
# cht.sh
# chunk.d.ts
# chunk.d.ts
# clamp.d.ts
# clamp.d.ts
# clangwrap.sh
# clean.bash
# clean.rc
# cli.js
# cli.js
# cli.js
# cli.js
# cli.js
# cli.js
# cloneDeep.d.ts
# cloneDeep.d.ts
# cloneDeepWith.d.ts
# cloneDeepWith.d.ts
# clone.d.ts
# clone.d.ts
# cloneWith.d.ts
# cloneWith.d.ts
# cmd.js
# cmd.js
# collection.d.ts
# commit-msg
# common.d.ts
# common_test.py
# compact.d.ts
# compact.d.ts
# compile
# compile.sh
# complement.d.ts
# completion.sh
# compose.d.ts
# concat.d.ts
# concat.d.ts
# cond.d.ts
# cond.d.ts
# configure
# conforms.d.ts
# conformsTo.d.ts
# conformsTo.d.ts
# constant.d.ts
# constant.d.ts
# contains.d.ts
# conversion.js
# convert.d.ts
# corepack.js
# countBy.d.ts
# countBy.d.ts
# cover
# cover.bash
# create.d.ts
# create.d.ts
# curry.d.ts
# curry.d.ts
# curryN.d.ts
# curryRight.d.ts
# curryRight.d.ts
# curryRightN.d.ts
# date.d.ts
# debounce.d.ts
# debounce.d.ts
# deburr.d.ts
# deburr.d.ts
# defaultsAll.d.ts
# defaultsDeepAll.d.ts
# defaultsDeep.d.ts
# defaultsDeep.d.ts
# defaults.d.ts
# defaults.d.ts
# defaultTo.d.ts
# defaultTo.d.ts
# defer.d.ts
# defer.d.ts
# delay.d.ts
# delay.d.ts
# differenceBy.d.ts
# differenceBy.d.ts
# difference.d.ts
# difference.d.ts
# differenceWith.d.ts
# differenceWith.d.ts
# dissoc.d.ts
# dissocPath.d.ts
# dist
# divide.d.ts
# divide.d.ts
# doc
# drop.d.ts
# drop.d.ts
# dropLast.d.ts
# dropLastWhile.d.ts
# dropRight.d.ts
# dropRight.d.ts
# dropRightWhile.d.ts
# dropRightWhile.d.ts
# dropWhile.d.ts
# dropWhile.d.ts
# __.d.ts
# each.d.ts
# each.d.ts
# eachRight.d.ts
# eachRight.d.ts
# easy_xml_test.py
# endsWith.d.ts
# endsWith.d.ts
# entries.d.ts
# entries.d.ts
# entriesIn.d.ts
# entriesIn.d.ts
# eq.d.ts
# eq.d.ts
# equals.d.ts
# escape.d.ts
# escape.d.ts
# escapeRegExp.d.ts
# escapeRegExp.d.ts
# esparse.js
# esparse.js
# esvalidate.js
# esvalidate.js
# every.d.ts
# every.d.ts
# executable-script.js
# experiment-haskell-io-exe
# extendAll.d.ts
# extendAllWith.d.ts
# extend.d.ts
# extend.d.ts
# extendWith.d.ts
# extendWith.d.ts
# fd
# F.d.ts
# fill.d.ts
# fill.d.ts
# filter.d.ts
# filter.d.ts
# find.d.ts
# find.d.ts
# findFrom.d.ts
# findIndex.d.ts
# findIndex.d.ts
# findIndexFrom.d.ts
# findKey.d.ts
# findKey.d.ts
# findLast.d.ts
# findLast.d.ts
# findLastFrom.d.ts
# findLastIndex.d.ts
# findLastIndex.d.ts
# findLastIndexFrom.d.ts
# findLastKey.d.ts
# findLastKey.d.ts
# first.d.ts
# first.d.ts
# fix
# flatMapDeep.d.ts
# flatMapDeep.d.ts
# flatMapDepth.d.ts
# flatMapDepth.d.ts
# flatMap.d.ts
# flatMap.d.ts
# flattenDeep.d.ts
# flattenDeep.d.ts
# flattenDepth.d.ts
# flattenDepth.d.ts
# flatten.d.ts
# flatten.d.ts
# flip.d.ts
# flip.d.ts
# flock_tool.py
# floor.d.ts
# floor.d.ts
# flow.d.ts
# flow.d.ts
# flowRight.d.ts
# flowRight.d.ts
# forEach.d.ts
# forEach.d.ts
# forEachRight.d.ts
# forEachRight.d.ts
# forIn.d.ts
# forIn.d.ts
# forInRight.d.ts
# forInRight.d.ts
# forOwn.d.ts
# forOwn.d.ts
# forOwnRight.d.ts
# forOwnRight.d.ts
# fp.d.ts
# fromPairs.d.ts
# fromPairs.d.ts
# function.d.ts
# functions.d.ts
# functions.d.ts
# functionsIn.d.ts
# functionsIn.d.ts
# get.d.ts
# get.d.ts
# getOr.d.ts
# gitui
# go
# gofmt
# go_js_wasm_exec
# graphviz.py
# grex
# groupBy.d.ts
# groupBy.d.ts
# gt.d.ts
# gt.d.ts
# gte.d.ts
# gte.d.ts
# gyp
# gyp.bat
# gyp_main.py
# h2o
# has.d.ts
# has.d.ts
# hasIn.d.ts
# hasIn.d.ts
# head.d.ts
# head.d.ts
# http.d.ts
# http.js
# http.js.map
# https.d.ts
# https.js
# https.js.map
# hyperfine
# identical.d.ts
# identity.d.ts
# identity.d.ts
# includes.d.ts
# includes.d.ts
# includesFrom.d.ts
# indexBy.d.ts
# index.d.ts
# index.d.ts
# index.d.ts
# index.d.ts
# index.d.ts
# index.d.ts
# index.js
# index.js
# index.js
# index.js
# index.js
# index.js
# index.js
# index.js
# index.js.map
# indexOf.d.ts
# indexOf.d.ts
# indexOfFrom.d.ts
# index.ts
# init.d.ts
# initial.d.ts
# initial.d.ts
# __init__.py
# input_test.py
# inRange.d.ts
# inRange.d.ts
# install
# intersectionBy.d.ts
# intersectionBy.d.ts
# intersection.d.ts
# intersection.d.ts
# intersectionWith.d.ts
# intersectionWith.d.ts
# invertBy.d.ts
# invertBy.d.ts
# invert.d.ts
# invert.d.ts
# invertObj.d.ts
# invokeArgs.d.ts
# invokeArgsMap.d.ts
# invoke.d.ts
# invoke.d.ts
# invokeMap.d.ts
# invokeMap.d.ts
# isArguments.d.ts
# isArguments.d.ts
# isArrayBuffer.d.ts
# isArrayBuffer.d.ts
# isArray.d.ts
# isArray.d.ts
# isArrayLike.d.ts
# isArrayLike.d.ts
# isArrayLikeObject.d.ts
# isArrayLikeObject.d.ts
# isBoolean.d.ts
# isBoolean.d.ts
# isBuffer.d.ts
# isBuffer.d.ts
# isDate.d.ts
# isDate.d.ts
# isElement.d.ts
# isElement.d.ts
# isEmpty.d.ts
# isEmpty.d.ts
# isEqual.d.ts
# isEqual.d.ts
# isEqualWith.d.ts
# isEqualWith.d.ts
# isError.d.ts
# isError.d.ts
# isFinite.d.ts
# isFinite.d.ts
# isFunction.d.ts
# isFunction.d.ts
# isInteger.d.ts
# isInteger.d.ts
# isLength.d.ts
# isLength.d.ts
# isMap.d.ts
# isMap.d.ts
# isMatch.d.ts
# isMatch.d.ts
# isMatchWith.d.ts
# isMatchWith.d.ts
# isNaN.d.ts
# isNaN.d.ts
# isNative.d.ts
# isNative.d.ts
# isNil.d.ts
# isNil.d.ts
# isNull.d.ts
# isNull.d.ts
# isNumber.d.ts
# isNumber.d.ts
# isObject.d.ts
# isObject.d.ts
# isObjectLike.d.ts
# isObjectLike.d.ts
# isPlainObject.d.ts
# isPlainObject.d.ts
# isRegExp.d.ts
# isRegExp.d.ts
# isSafeInteger.d.ts
# isSafeInteger.d.ts
# isSet.d.ts
# isSet.d.ts
# isString.d.ts
# isString.d.ts
# isSymbol.d.ts
# isSymbol.d.ts
# isTypedArray.d.ts
# isTypedArray.d.ts
# isUndefined.d.ts
# isUndefined.d.ts
# isWeakMap.d.ts
# isWeakMap.d.ts
# isWeakSet.d.ts
# isWeakSet.d.ts
# iteratee.d.ts
# iteratee.d.ts
# join.d.ts
# join.d.ts
# jParser.sh
# js-yaml.js
# js-yaml.js
# julia
# julia-config.jl
# juxt.d.ts
# kebabCase.d.ts
# kebabCase.d.ts
# keyBy.d.ts
# keyBy.d.ts
# keys.d.ts
# keys.d.ts
# keysIn.d.ts
# keysIn.d.ts
# keytar.node
# lang.d.ts
# last.d.ts
# last.d.ts
# lastIndexOf.d.ts
# lastIndexOf.d.ts
# lastIndexOfFrom.d.ts
# libamd.so.2.4.6
# libatomic.so.1.2.0
# libblastrampoline.so
# libbtf.so.1.2.6
# libcamd.so.2.4.6
# libccalltest.so
# libccalltest.so.debug
# libccolamd.so.2.9.6
# libcholmod.so.3.0.14
# libcolamd.so.2.9.6
# libcurl.so.4.7.0
# libdSFMT.so
# libgcc_s.so.1
# libgfortran.so.5.0.0
# libgit2.so.1.1.0
# libgmp.so.10.4.1
# libgmpxx.so.4.6.1
# libgomp.so.1.0.0
# libjulia-internal.so.1.7
# libjulia.so.1.7
# libklu.so.1.3.8
# libldl.so.2.2.6
# libLLVM-12jl.so
# libllvmcalltest.so
# libmbedcrypto.so.2.24.0
# libmbedtls.so.2.24.0
# libmbedx509.so.2.24.0
# libmpfr.so.6.1.0
# libnghttp2.so.14.20.0
# libopenblas64_.0.3.13.so
# libopenlibm.so.3.0
# libpcre2-8.so.0.10.1
# libquadmath.so.0.0.0
# librbio.so.2.2.6
# libspqr.so.2.0.9
# libssh2.so.1.0.1
# libstdc++.so.6.0.29
# libsuitesparseconfig.so.5.10.1
# libumfpack.so.5.7.9
# libunwind.so.8.0.1
# libuv.so.2.0.0
# libz.so.1.2.11
# LICENSE
# LICENSE
# LICENSE
# LICENSE
# LICENSE
# LICENSE
# LICENSE
# LICENSE
# link
# lowerCase.d.ts
# lowerCase.d.ts
# lowerFirst.d.ts
# lowerFirst.d.ts
# lt.d.ts
# lt.d.ts
# lte.d.ts
# lte.d.ts
# mac_tool.py
# mailto.d.ts
# mailto.js
# mailto.js.map
# make.bash
# make_perl_groups.pl
# make.rc
# map.d.ts
# map.d.ts
# mapKeys.d.ts
# mapKeys.d.ts
# mapValues.d.ts
# mapValues.d.ts
# markdown-it.js
# matches.d.ts
# matches.d.ts
# matchesProperty.d.ts
# matchesProperty.d.ts
# math.d.ts
# maxBy.d.ts
# maxBy.d.ts
# max.d.ts
# max.d.ts
# meanBy.d.ts
# meanBy.d.ts
# mean.d.ts
# mean.d.ts
# memoize.d.ts
# memoize.d.ts
# mergeAll.d.ts
# mergeAllWith.d.ts
# merge.d.ts
# merge.d.ts
# mergeWith.d.ts
# mergeWith.d.ts
# method.d.ts
# method.d.ts
# methodOf.d.ts
# methodOf.d.ts
# minBy.d.ts
# minBy.d.ts
# min.d.ts
# min.d.ts
# minifyStyles.js
# mixin.d.ts
# mkalldocs.sh
# mkall.sh
# mkcanned.bash
# mkerrors.sh
# mksyscall_libc.pl
# mksyscall.pl
# mksysctl_openbsd.pl
# mksysnum_dragonfly.pl
# mksysnum_freebsd.pl
# mksysnum_linux.pl
# mksysnum_netbsd.pl
# mksysnum_openbsd.pl
# mksysnum_plan9.sh
# MSVSSettings_test.py
# msvs_test.py
# multiply.d.ts
# multiply.d.ts
# nAry.d.ts
# negate.d.ts
# negate.d.ts
# nm
# noConflict.d.ts
# noConflict.d.ts
# node
# node-gyp
# node-gyp
# node-gyp.cmd
# node-gyp.cmd
# node-gyp.js
# node-which
# noop.d.ts
# noop.d.ts
# nopt.js
# now.d.ts
# now.d.ts
# npm
# npm
# npm-cli.js
# npm.cmd
# npm.js
# npm.ps1
# npx
# npx
# npx-cli.js
# npx.cmd
# npx.js
# npx.ps1
# nthArg.d.ts
# nthArg.d.ts
# nth.d.ts
# nth.d.ts
# number.d.ts
# nvim.appimage
# objdump
# object.d.ts
# oc
# oil.ovm
# omitAll.d.ts
# omitBy.d.ts
# omitBy.d.ts
# omit.d.ts
# omit.d.ts
# once.d.ts
# once.d.ts
# opener-bin.js
# orderBy.d.ts
# orderBy.d.ts
# overArgs.d.ts
# overArgs.d.ts
# over.d.ts
# over.d.ts
# overEvery.d.ts
# overEvery.d.ts
# overSome.d.ts
# overSome.d.ts
# ovm-opt
# ovm-opt.stripped
# ovm-opt.symbols
# pack
# package.json
# package.json
# package.json
# package.json
# package.json
# package.json
# package.json
# package.json
# padChars.d.ts
# padCharsEnd.d.ts
# padCharsStart.d.ts
# pad.d.ts
# pad.d.ts
# padEnd.d.ts
# padEnd.d.ts
# padStart.d.ts
# padStart.d.ts
# parseInt.d.ts
# parseInt.d.ts
# partial.d.ts
# partial.d.ts
# partialRight.d.ts
# partialRight.d.ts
# partition.d.ts
# partition.d.ts
# path.d.ts
# pathEq.d.ts
# pathOr.d.ts
# paths.d.ts
# pickAll.d.ts
# pickBy.d.ts
# pickBy.d.ts
# pick.d.ts
# pick.d.ts
# pip
# pip3
# pip3.10
# pipe.d.ts
# placeholder.d.ts
# pluck.d.ts
# pnpm
# pnpm.js
# pnpm.ps1
# pnpx
# pnpx.js
# pnpx.ps1
# pprof
# pre-commit
# prefixIds.js
# pretty_gyp.py
# pretty_sln.py
# pretty_vcproj.py
# prop.d.ts
# propEq.d.ts
# property.d.ts
# property.d.ts
# propertyOf.d.ts
# propertyOf.d.ts
# propOr.d.ts
# props.d.ts
# pullAllBy.d.ts
# pullAllBy.d.ts
# pullAll.d.ts
# pullAll.d.ts
# pullAllWith.d.ts
# pullAllWith.d.ts
# pullAt.d.ts
# pullAt.d.ts
# pull.d.ts
# pull.d.ts
# qrcode-terminal.js
# race.bash
# random.d.ts
# random.d.ts
# range.d.ts
# range.d.ts
# rangeRight.d.ts
# rangeRight.d.ts
# ranges.elf
# rangeStep.d.ts
# rangeStepRight.d.ts
# README.md
# README.md
# README.md
# README.md
# README.md
# README.md
# README.md
# rearg.d.ts
# rearg.d.ts
# reduce.d.ts
# reduce.d.ts
# reduceRight.d.ts
# reduceRight.d.ts
# regexps-iri.d.ts
# regexps-iri.js
# regexps-iri.js.map
# regexps-uri.d.ts
# regexps-uri.js
# regexps-uri.js.map
# reject.d.ts
# reject.d.ts
# removecolor
# remove.d.ts
# remove.d.ts
# repeat.d.ts
# repeat.d.ts
# replace.d.ts
# replace.d.ts
# resolve
# rest.d.ts
# rest.d.ts
# restFrom.d.ts
# result.d.ts
# result.d.ts
# reverse.d.ts
# reverse.d.ts
# rga
# rga-preproc
# rnglistx.elf
# round.d.ts
# round.d.ts
# run.bash
# runInContext.d.ts
# runInContext.d.ts
# run.rc
# run-unit-tests.sh
# sample.d.ts
# sample.d.ts
# sampleSize.d.ts
# sampleSize.d.ts
# sanitize_unicode.py
# semver
# semver
# semver.js
# semver.js
# seq.d.ts
# set.d.ts
# set.d.ts
# setWith.d.ts
# setWith.d.ts
# shuffle.d.ts
# shuffle.d.ts
# size.d.ts
# size.d.ts
# slice.d.ts
# slice.d.ts
# snakeCase.d.ts
# snakeCase.d.ts
# some.d.ts
# some.d.ts
# sortBy.d.ts
# sortBy.d.ts
# sortedIndexBy.d.ts
# sortedIndexBy.d.ts
# sortedIndex.d.ts
# sortedIndex.d.ts
# sortedIndexOf.d.ts
# sortedIndexOf.d.ts
# sortedLastIndexBy.d.ts
# sortedLastIndexBy.d.ts
# sortedLastIndex.d.ts
# sortedLastIndex.d.ts
# sortedLastIndexOf.d.ts
# sortedLastIndexOf.d.ts
# sortedUniqBy.d.ts
# sortedUniqBy.d.ts
# sortedUniq.d.ts
# sortedUniq.d.ts
# split.d.ts
# split.d.ts
# spread.d.ts
# spread.d.ts
# spreadFrom.d.ts
# ssh
# stack
# startCase.d.ts
# startCase.d.ts
# startsWith.d.ts
# startsWith.d.ts
# string.d.ts
# stubArray.d.ts
# stubFalse.d.ts
# stubFalse.d.ts
# stubObject.d.ts
# stubString.d.ts
# stubTrue.d.ts
# stubTrue.d.ts
# subtract.d.ts
# subtract.d.ts
# sumBy.d.ts
# sumBy.d.ts
# sum.d.ts
# sum.d.ts
# svgo
# svgo.js
# symmetricDifferenceBy.d.ts
# symmetricDifference.d.ts
# symmetricDifferenceWith.d.ts
# sys.so
# table2asn
# tail.d.ts
# tail.d.ts
# take.d.ts
# take.d.ts
# takeLast.d.ts
# takeLastWhile.d.ts
# takeRight.d.ts
# takeRight.d.ts
# takeRightWhile.d.ts
# takeRightWhile.d.ts
# takeWhile.d.ts
# takeWhile.d.ts
# tap.d.ts
# tap.d.ts
# T.d.ts
# template.d.ts
# template.d.ts
# terraform
# test2json
# test32
# test32be
# test64
# test64be
# test.bash
# test.cgi
# test_gyp.py
# throttle.d.ts
# throttle.d.ts
# thru.d.ts
# thru.d.ts
# times.d.ts
# times.d.ts
# tldr
# tmux
# toArray.d.ts
# toArray.d.ts
# toFinite.d.ts
# toFinite.d.ts
# toInteger.d.ts
# toInteger.d.ts
# toLength.d.ts
# toLength.d.ts
# toLower.d.ts
# toLower.d.ts
# toNumber.d.ts
# toNumber.d.ts
# toPairs.d.ts
# toPairs.d.ts
# toPairsIn.d.ts
# toPairsIn.d.ts
# toPath.d.ts
# toPath.d.ts
# topgrade
# toPlainObject.d.ts
# toPlainObject.d.ts
# toSafeInteger.d.ts
# toSafeInteger.d.ts
# toString.d.ts
# toString.d.ts
# toUpper.d.ts
# toUpper.d.ts
# trace
# transform.d.ts
# transform.d.ts
# trimChars.d.ts
# trimCharsEnd.d.ts
# trimCharsStart.d.ts
# trim.d.ts
# trim.d.ts
# trimEnd.d.ts
# trimEnd.d.ts
# trimStart.d.ts
# trimStart.d.ts
# truncate.d.ts
# truncate.d.ts
# tsc
# tsserver
# typedef.elf
# unapply.d.ts
# unary.d.ts
# unary.d.ts
# unescape.d.ts
# unescape.d.ts
# uninstall
# unionBy.d.ts
# unionBy.d.ts
# union.d.ts
# union.d.ts
# unionWith.d.ts
# unionWith.d.ts
# uniqBy.d.ts
# uniqBy.d.ts
# uniq.d.ts
# uniq.d.ts
# uniqueId.d.ts
# uniqueId.d.ts
# uniqWith.d.ts
# uniqWith.d.ts
# unnest.d.ts
# unset.d.ts
# unset.d.ts
# unzip.d.ts
# unzip.d.ts
# unzipWith.d.ts
# unzipWith.d.ts
# update.bash
# update.d.ts
# update.d.ts
# update-gyp.py
# updateWith.d.ts
# updateWith.d.ts
# upperCase.d.ts
# upperCase.d.ts
# upperFirst.d.ts
# upperFirst.d.ts
# uri.all.d.ts
# uri.all.js
# uri.all.js.map
# uri.all.min.d.ts
# uri.all.min.js
# uri.all.min.js.map
# uri.d.ts
# uri.js
# uri.js.map
# urn.d.ts
# urn.js
# urn.js.map
# urn-uuid.d.ts
# urn-uuid.js
# urn-uuid.js.map
# useWith.d.ts
# utf16_chinese.plist
# util.d.ts
# util.d.ts
# util.js
# util.js.map
# uuid
# values.d.ts
# values.d.ts
# valuesIn.d.ts
# valuesIn.d.ts
# vet
# vsce
# where.d.ts
# whereEq.d.ts
# which
# win_tool.py
# without.d.ts
# without.d.ts
# words.d.ts
# words.d.ts
# wrap.d.ts
# wrap.d.ts
# ws.d.ts
# ws.js
# ws.js.map
# wss.d.ts
# wss.js
# wss.js.map
# xorBy.d.ts
# xorBy.d.ts
# xor.d.ts
# xor.d.ts
# xorWith.d.ts
# xorWith.d.ts
# yarn
# yarn.js
# yarn.lock
# yarnpkg
# yarnpkg.js
# yarnpkg.ps1
# yarn.ps1
# yq
# zipAll.d.ts
# zip.d.ts
# zip.d.ts
# zipObj.d.ts
# zipObjectDeep.d.ts
# zipObjectDeep.d.ts
# zipObject.d.ts
# zipObject.d.ts
# zipWith.d.ts
# zipWith.d.ts
# zoxide
