# %% [markdown]
# # Getting Started with Triton Notebook

# %% [markdown]
# A cell is either **Markdown mode** or **Code mode** as indicated in the toolbar above. Code mode is where we enter shell command or Python/R code.
#
#
# Type `%%bash` at the top of a cell to enter a shell command/script.

# %%
# %%bash
#
# echo "hello world"
# Out:
# hello world

# %% [markdown]
# # Bioinformatics notebook

# %% [markdown]
# Here is a list of bioinformatics tools available in the system.

# %%
# %%bash
#
# find ~/.local/bin -type f -or -type l -executable -print0 | xargs -0 basename -a | sort
# Out:
# abba-baba
# abundance_estimates_to_matrix.pl
# ace2sam
# ajv
# align_and_estimate_abundance.pl
# alignGFA
# analyze_blastPlus_topHit_coverage.pl
# analyze_diff_expr.pl
# annotateBed
# arborist
# bakta
# bakta_db
# bamleftalign
# bamToBed
# bamToFastq
# bcftools
# bed12ToBed6
# bed2region
# bedpeToBam
# bedToBam
# bedToIgv
# bedtools
# bFst
# bgzip
# bgziptabix
# bioawk
# blast2sam.pl
# bogart
# bowtie2sam.pl
# bwa
# bwa-mem2
# bwa-mem2.avx
# bwa-mem2.avx2
# bwa-mem2.avx512bw
# bwa-mem2.sse41
# bwa-mem2.sse42
# canu
# canu.defaults
# canu-time
# cds-mapping-stats
# cds-subgraphs
# checkm
# .checkm-genome-post-link.sh
# .checkm-genome-pre-unlink.sh
# check-updates-utils
# closestBed
# clusterBed
# color-chrs.pl
# color-support
# combineMUMs
# complementBed
# contig_ExN50_statistic.pl
# convert-sam-for-rsem
# corepack
# coronaspades.py
# correctOverlaps
# coverageBed
# coverage_to_regions.py
# cuffcompare
# cuffdiff
# cufflinks
# cuffmerge
# cuffnorm
# cuffquant
# ...
